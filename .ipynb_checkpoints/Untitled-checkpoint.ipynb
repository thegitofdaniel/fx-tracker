# %%
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

# %%
import investpy as inv

# %%
fundos_br = inv.get_funds_list(country='brazil')
print(len(fundos_br))
# Out:
# 5200

# %%
query = inv.search_funds(by='name',value='BTG')
query.head()
# Out:
#   country                                               name      symbol  \
# 0  brazil  Btg Pactual Infraestrutura Ii Feeder Fic Fi Mu...  0P0000WVGC
# 1  brazil  Btg Pactual Multistrategies Advanced Fundo De ...  0P0000U9QH
# 2  brazil  Btg Pactual Hedge Fundo De Investimento Multim...  0P0000U8SL
# 3  brazil  Btgp Access Balanceado Fundo De Investimento E...  0P0000U8TA
# 4  brazil  Btg Pactual Multistrategies Advanced Plus Fund...  0P0000U9QE
#
#                                    issuer          isin asset_class currency  \
# 0  BTG Pactual WM Gestão de Recursos Ltda  BRFEE9CTF000       other      BRL
# 1    BTG Pactual Asset Management SA DTVM  BRPMADCTF005       other      BRL
# 2    BTG Pactual Asset Management SA DTVM  BRPCHECTF009       other      BRL
# 3  BTG Pactual WM Gestão de Recursos Ltda  BRUBSPCTF004       other      BRL
# 4    BTG Pactual Asset Management SA DTVM  BRMTS2CTF003       other      BRL
#
#   underlying
# 0
# 1
# 2
# 3
# 4

# %%
fundo_nome = query['name'][0]

# %%
fundo_dados_historicos = inv.get_fund_historical_data(fundo_nome,country='brazil',from_date='01/01/1900',to_date='07/02/2022')

# %%
fundo_dados_historicos["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
etfs_brazil = inv.get_etfs_overview(country='brazil')

# %%
etfs_brazil.head()
# Out:
#   country                              name  \
# 0  brazil                  Ishares Ibovespa
# 1  brazil  QR CME CF Bitcoin Reference Rate
# 2  brazil                    Trend Ibovespa
# 3  brazil   It Now Ibovespa Fundo De Indice
# 4  brazil             Hashdex Nasdaq Crypto
#
#                                            full_name  symbol    last  change  \
# 0                                   Ishares Ibovespa  BOVA11  108.04  +0.02%
# 1  QR CME CF Bitcoin Reference Rate Fundo de Índi...  QBTC11   14.60  +6.18%
# 2                 Trend ETF Ibovespa Fundo de Índice  BOVX11   11.21  -0.09%
# 3                    It Now Ibovespa Fundo De Indice  BOVV11  112.98  -0.22%
# 4        Hashdex NASDAQ Crypto Index Fundo de Índice  HASH11   42.40  +7.51%
#
#    turnover currency
# 0   5610000      BRL
# 1   1860000      BRL
# 2   1050000      BRL
# 3    926350      BRL
# 4    912620      BRL

# %%
bova11 = inv.get_etf_historical_data('Ishares Ibovespa',country='brazil',from_date='01/01/1900',to_date='07/02/2022')

# %%
bova11['Close'].plot();

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (16,8)

# %%
fundos_br
# Out:
# ['Fundo De Investimento Multimercado Bordeaux Iv Crédito Privado Investimento No Exterior',
#  'Cshg Warrior V Fundo De Investimento Multimercado - Crédito Privado Investimento No Exterior',
#  'A3 Viking Fi Em Quotas De Fi Multimercado Crédito Privado Investimento No Exterior',
#  'Bb Espelho Multimercado Lp J. Safra Absoluto 30 Private Fic Fi',
#  'Ctm Hedge Fundo De Investimento Multimercado - Longo Prazo',
#  'Vif - Fundo De Investimento Em Cotas De Fundos De Investimento Multimercado',
#  'Fundo De Investimento Multimercado Bordeaux Iii Crédito Privado Investimento No Exterior',
#  'Bb Top Tatico Fundo De Investimento Multimercado',
#  'Epm Fundo De Investimento Multimercado Crédito Privado Investimento No Exterior',
#  'Western Asset Multitrading H Multimercado Fundo De Investimento',
#  'Concordia Phoenix Fundo De Investimento Multimercado Crédito Privado',
#  'Fundo De Investimento Multimercado Irmb Crédito Privado - Investimento No Exterior',
# ...
